# %% [markdown]
# 1. 지금까지 했던 수준에 한해서만 데이터를 Pandas로 다양하게 처리
# 2. 혼자? 둘이? 셋이? 4:1 ...
# 3. 마무리 시간 : 5시30분까지 제출
# 4. 이재선 검수 및 선택 - 다른 친구들 모든 작품 보고 한작품 선정(발표시킬 예정)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborns as sns
from matplotlib import font_manager, rc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-51-be82310410f8> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborns as sns
#       5 from matplotlib import font_manager, rc
#
# ModuleNotFoundError: No module named 'seaborns'

# %%
df = pd.read_csv('./dataset/profile_20201231.csv', encoding='euc-kr')
df
# Out:
#         구분 시설종류     공종명        객체       위치   작업프로세스                원인  물적피해  \
# 0   201801   토목  콘크리트공사        벽체       인접     철근조립          전도방지 미조치   넘어짐
# 1   201802   건축    리모델링       슬래브       하부       보강           구조검토 미흡   무너짐
# 2   201803   건축    마감공사    외벽작업발판       고소       마감           앵커 시공불량   무너짐
# 3   201804   건축    철골공사    이동식크레인       인접       양중           빠른 선회속도   넘어짐
# 4   201805   건축    설비공사  이동식 가설구대       고소   천장설비설치     가설구대 이동속도 불균형   무너짐
# 5   201806   토목  콘크리트공사       브라켓       하부  PC부재 조립            철근 미시공    파괴
# 6   201807   건축    설비공사       단열재       인접       용접              용접불티    화재
# 7   201808   토목    유지보수      점검계단       고소       이동           앵커 시공불량   무너짐
# 8   201809   토목    옹벽공사      성토사면       인접       다짐            경사도 불량   무너짐
# 9   201810   건축    해체공사       구조물     철거방향       철거           횡하중(철거)   넘어짐
# 10  201811   건축    가설공사       거푸집       인접     비계설치              임의해체   넘어짐
# ...

# %%
df.groupby('시설종류').size()
# Out:
# 시설종류
# 건축    39
# 토목    17
# dtype: int64

# %%
df[df['시설종류'] == '건축']
# Out:
#         구분 시설종류     공종명        객체       위치  작업프로세스                원인  물적피해  \
# 1   201802   건축    리모델링       슬래브       하부      보강           구조검토 미흡   무너짐
# 2   201803   건축    마감공사    외벽작업발판       고소      마감           앵커 시공불량   무너짐
# 3   201804   건축    철골공사    이동식크레인       인접      양중           빠른 선회속도   넘어짐
# 4   201805   건축    설비공사  이동식 가설구대       고소  천장설비설치     가설구대 이동속도 불균형   무너짐
# 6   201807   건축    설비공사       단열재       인접      용접              용접불티    화재
# 9   201810   건축    해체공사       구조물     철거방향      철거           횡하중(철거)   넘어짐
# 10  201811   건축    가설공사       거푸집       인접    비계설치              임의해체   넘어짐
# 11  201812   건축    방수공사       유증기      지하층      방수                폭발    화재
# 12  201813   건축    설비공사       단열재       인접      용접              용접불티    화재
# 14  201815   건축    굴착공사       흙막이       상부      굴착              차수불량   무너짐
# 15  201816   건축    굴착공사       흙막이       상부      굴착              설계불량   무너짐
# ...

# %%
# df = Series(np.arange(10)) df.map(lambda x: x**2).head(5)
# Out:
#   File "<ipython-input-33-27b13368e8cc>", line 1
#     df = Series(np.arange(10)) df.map(lambda x: x**2).head(5)
#                                ^
# SyntaxError: invalid syntax

# %%
df.groupby('인적피해').size()
# Out:
# 인적피해
# 깔림     16
# 넘어짐     1
# 떨어짐    17
# 맞음      4
# 부딪힘     1
# 없음      9
# 익사      1
# 질식      7
# dtype: int64

# %%
df.sort_values(by='인적피해', ascending=False)

# %%
mg = df.groupby('인적피해')
df1 = pd.DataFrame({'count' : mg.size()}).reset_index()
df1
# Out:
#   인적피해  count
# 0   깔림     16
# 1  넘어짐      1
# 2  떨어짐     17
# 3   맞음      4
# 4  부딪힘      1
# 5   없음      9
# 6   익사      1
# 7   질식      7

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
df.공종명.value_counts().plot.bar();

# %%
df1.plot()
plt.title("인적피해 그래프")
plt.xlabel("인적피해")
plt.ylabel("수")
plt.show()

# %%
c=['무너짐','넘어짐','화재','없음','떨어짐','낙하','파괴','기울어짐','붕락','붕괴']
d=df['물적피해'].value_counts()
plt.figure(figsize=(10,10)) ## Figure 생성 사이즈는 10 by 10
# xtick_label_position = list(range(len(age_category))) ## x축 눈금 라벨이 표시될 x좌표
# plt.xticks(xtick_label_position, age_category) ## x축 눈금 라벨 출력
## 바 차트 출력, 막대기 색깔을 초록색으로 설정
plt.bar(c,d, color='green')
plt.title('물적피해 카운트',fontsize=20) ## 타이틀 출력
plt.xlabel('숫자') ## x축 라벨 출력
plt.ylabel('물적피해') ## y축 라벨 출력
# Out:
# Text(0, 0.5, '물적피해')

# %%
image = sns.df1

# %%
df1[df1['count'] >= 10]
# Out:
#   인적피해  count
# 0   깔림     16
# 2  떨어짐     17

# %%
df2 = df.groupby(['인적피해', '물적피해']).count()
df2
# Out:
#            구분  시설종류  공종명  객체  위치  작업프로세스  원인
# 인적피해 물적피해
# 깔림   넘어짐    2     2    2   2   2       2   2
#      무너짐   10    10   10  10  10      10  10
#      붕괴     1     1    1   1   1       1   1
#      붕락     1     1    1   1   1       1   1
#      없음     1     1    1   1   1       1   1
#      파괴     1     1    1   1   1       1   1
# 넘어짐  무너짐    1     1    1   1   1       1   1
# 떨어짐  낙하     1     1    1   1   1       1   1
#      넘어짐    1     1    1   1   1       1   1
#      떨어짐    1     1    1   1   1       1   1
#      무너짐   12    12   12  12  12      12  12
#      없음     2     2    2   2   2       2   2
# 맞음   낙하     1     1    1   1   1       1   1
#      넘어짐    2     2    2   2   2       2   2
#      떨어짐    1     1    1   1   1       1   1
# 부딪힘  넘어짐    1     1    1   1   1       1   1
# 없음   기울어짐   1     1    1   1   1       1   1
#      넘어짐    4     4    4   4   4       4   4
#      떨어짐    1     1    1   1   1       1   1
#      무너짐    2     2    2   2   2       2   2
# ...

# %%
df2 = df.groupby(['인적피해', '물적피해']).count().reset_index()
df2
# Out:
#    인적피해  물적피해  구분  시설종류  공종명  객체  위치  작업프로세스  원인
# 0    깔림   넘어짐   2     2    2   2   2       2   2
# 1    깔림   무너짐  10    10   10  10  10      10  10
# 2    깔림    붕괴   1     1    1   1   1       1   1
# 3    깔림    붕락   1     1    1   1   1       1   1
# 4    깔림    없음   1     1    1   1   1       1   1
# 5    깔림    파괴   1     1    1   1   1       1   1
# 6   넘어짐   무너짐   1     1    1   1   1       1   1
# 7   떨어짐    낙하   1     1    1   1   1       1   1
# 8   떨어짐   넘어짐   1     1    1   1   1       1   1
# 9   떨어짐   떨어짐   1     1    1   1   1       1   1
# 10  떨어짐   무너짐  12    12   12  12  12      12  12
# 11  떨어짐    없음   2     2    2   2   2       2   2
# 12   맞음    낙하   1     1    1   1   1       1   1
# 13   맞음   넘어짐   2     2    2   2   2       2   2
# 14   맞음   떨어짐   1     1    1   1   1       1   1
# 15  부딪힘   넘어짐   1     1    1   1   1       1   1
# 16   없음  기울어짐   1     1    1   1   1       1   1
# 17   없음   넘어짐   4     4    4   4   4       4   4
# ...
